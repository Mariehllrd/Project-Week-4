# %% [markdown]
# ## Importing librairies

# %%
import pandas as pd
import numpy as np
import fuzzy_pandas as fpd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Survey Dataset

# %% [markdown]
# ### Content to keep:
# #### Sheet:
# - Crosstabs all countries
#
# #### Questions:
# - Q24 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are important for children to have.
# - Q25 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are safe.
# - Q26 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are effective.
#
# #### Columns
# - Country
# - Question
# - Response
# - National (%, count)

# %%
path = './datasets/wgm2018-dataset-crosstabs-all-countries.xlsx'
survey = pd.read_excel(path, sheet_name = 'Crosstabs all countries', index = [3], header = [2])
survey.head()
# Out:
#        Country                                           Question  \
# 0  Afghanistan  Q1 How much do you, personally, know about sci...
# 1  Afghanistan  Q1 How much do you, personally, know about sci...
# 2  Afghanistan  Q1 How much do you, personally, know about sci...
# 3  Afghanistan  Q1 How much do you, personally, know about sci...
# 4  Afghanistan  Q1 How much do you, personally, know about sci...
#
#          Response  Column N %  Unweighted Count  Column N %.1  \
# 0           A lot    0.024561                30      0.045239
# 1            Some    0.337138               393      0.416994
# 2        Not much    0.309527               287      0.347420
# 3  Nothing at all    0.292751               257      0.188135
# 4            (DK)    0.036023                33      0.002212
#
#    Unweighted Count.1  Column N %.2  Unweighted Count.2  Column N %.3  ...  \
# 0                  23      0.004403                   7      0.029301  ...
# 1                 230      0.259290                 163      0.408161  ...
# 2                 170      0.272586                 117      0.283687  ...
# 3                  75      0.394737                 182      0.244218  ...
# 4                   2      0.068984                  31      0.034633  ...
#
#    Column N %.16  Unweighted Count.16  Column N %.17  Unweighted Count.17  \
# 0       0.022139                    4       0.049635                   14
# 1       0.355557                   76       0.472349                  138
# 2       0.290543                   57       0.275725                   68
# 3       0.298553                   58       0.185203                   41
# 4       0.033208                    6       0.017088                    5
#
#    Column N %.18  Unweighted Count.18  Column N %.19  Unweighted Count.19  \
# 0            0.0                    0       0.044383                    6
# 1            0.0                    0       0.479065                   61
# 2            0.0                    0       0.338818                   32
# 3            0.0                    0       0.137733                   12
# 4            0.0                    0       0.000000                    0
#
#    Column N %.20  Unweighted Count.20
# 0       0.022938                   24
# 1       0.320562                  326
# 2       0.307318                  251
# 3       0.310804                  244
# 4       0.038378                   32
#
# [5 rows x 45 columns]

# %%
# Rename columns
survey = survey.rename(columns = {'Column N %':'Percentage', 'Unweighted Count':'Count'})

# %%
# Keeping only national results
survey = survey.iloc[:, :5]
survey
# Out:
#            Country                                           Question  \
# 0      Afghanistan  Q1 How much do you, personally, know about sci...
# 1      Afghanistan  Q1 How much do you, personally, know about sci...
# 2      Afghanistan  Q1 How much do you, personally, know about sci...
# 3      Afghanistan  Q1 How much do you, personally, know about sci...
# 4      Afghanistan  Q1 How much do you, personally, know about sci...
# ...            ...                                                ...
# 35840     Zimbabwe  How a person views personal & societal benefit...
# 35841     Zimbabwe  How a person views personal & societal benefit...
# 35842     Zimbabwe  How a person views personal & societal benefit...
# 35843     Zimbabwe  How a person views personal & societal benefit...
# 35844     Zimbabwe  How a person views personal & societal benefit...
#
#                                   Response  Percentage  Count
# 0                                    A lot    0.024561     30
# 1                                     Some    0.337138    393
# 2                                 Not much    0.309527    287
# 3                           Nothing at all    0.292751    257
# 4                                     (DK)    0.036023     33
# ...                                    ...         ...    ...
# 35840                             Included    0.247805    250
# 35841                             Excluded    0.107581    106
# 35842                              Sceptic    0.076144     78
# 35843  Did not answer one of two questions    0.112203     92
# 35844                                Total    1.000000   1000
#
# [35845 rows x 5 columns]

# %%
# Keeping only rows with Q24, 25 and 26
survey = survey.loc[(survey.Question.str.contains('Q24', case = False)) 
                   | (survey.Question.str.contains('Q25', case = False))
                   | (survey.Question.str.contains('Q26', case = False))]
survey
# Out:
#            Country                                           Question  \
# 166    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 167    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 168    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 169    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 170    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# ...            ...                                                ...
# 35808     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35809     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35810     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35811     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35812     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
#
#                          Response  Percentage  Count
# 166                Strongly agree    0.846256    843
# 167                Somewhat agree    0.129257    126
# 168    Neither agree nor disagree    0.003520      3
# 169             Somewhat disagree    0.015567     15
# 170             Strongly disagree    0.005400      6
# ...                           ...         ...    ...
# 35808  Neither agree nor disagree    0.055830     47
# 35809           Somewhat disagree    0.009500     10
# 35810           Strongly disagree    0.009019      7
# 35811          Don't know/Refused    0.009236      8
# 35812                       Total    1.000000    886
#
# [2997 rows x 5 columns]

# %%
# Column N % in %
survey['Percentage'] = [round(x * 100, 2) for x in survey['Percentage']]
survey
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Country                                           Question  \
# 166    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 167    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 168    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 169    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 170    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# ...            ...                                                ...
# 35808     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35809     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35810     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35811     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35812     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
#
#                          Response  Percentage  Count
# 166                Strongly agree       84.63    843
# 167                Somewhat agree       12.93    126
# 168    Neither agree nor disagree        0.35      3
# 169             Somewhat disagree        1.56     15
# 170             Strongly disagree        0.54      6
# ...                           ...         ...    ...
# 35808  Neither agree nor disagree        5.58     47
# 35809           Somewhat disagree        0.95     10
# 35810           Strongly disagree        0.90      7
# 35811          Don't know/Refused        0.92      8
# 35812                       Total      100.00    886
#
# [2997 rows x 5 columns]

# %%
# Keeping only disagree responses
survey = survey.loc[(survey.Response.str.contains('Somewhat disagree', case = False)) 
                   | (survey.Response.str.contains('Strongly disagree', case = False))]
survey
# Out:
#            Country                                           Question  \
# 169    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 170    Afghanistan  Q24 Do you strongly or somewhat agree, strongl...
# 175    Afghanistan  Q25 Do you strongly or somewhat agree, strongl...
# 176    Afghanistan  Q25 Do you strongly or somewhat agree, strongl...
# 182    Afghanistan  Q26 Do you strongly or somewhat agree, strongl...
# ...            ...                                                ...
# 35797     Zimbabwe  Q24 Do you strongly or somewhat agree, strongl...
# 35802     Zimbabwe  Q25 Do you strongly or somewhat agree, strongl...
# 35803     Zimbabwe  Q25 Do you strongly or somewhat agree, strongl...
# 35809     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
# 35810     Zimbabwe  Q26 Do you strongly or somewhat agree, strongl...
#
#                 Response  Percentage  Count
# 169    Somewhat disagree        1.56     15
# 170    Strongly disagree        0.54      6
# 175    Somewhat disagree        3.55     35
# 176    Strongly disagree        0.92     10
# 182    Somewhat disagree        1.07     11
# ...                  ...         ...    ...
# 35797  Strongly disagree        0.50      6
# 35802  Somewhat disagree        1.86     18
# 35803  Strongly disagree        1.90     18
# 35809  Somewhat disagree        0.95     10
# 35810  Strongly disagree        0.90      7
#
# [849 rows x 5 columns]

# %%
# Cleaning name
survey['Country'] = survey['Country'].apply(lambda x: x.split(',')[0])
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Pivot table by country - grouping disagree responses

survey_pivot = pd.pivot_table(index = 'Country', columns = 'Question', 
                       values = 'Percentage', aggfunc = 'sum', data = survey)
survey_pivot.rename(columns={'Q24 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are important for children to have.':
                             'Vaccines are not important for children to have (%)', 
                             'Q25 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are safe.':
                             'Vaccines are not safe (%)', 
                             'Q26 Do you strongly or somewhat agree, strongly or somewhat disagree or neither agree nor disagree with the following statement? Vaccines are effective.':
                            'Vaccines are not effective (%)'}, inplace=True)
survey_pivot
# Out:
# Question     Vaccines are not important for children to have (%)  \
# Country
# Afghanistan                                               2.10
# Albania                                                   1.67
# Algeria                                                   3.70
# Argentina                                                 1.21
# Armenia                                                  12.18
# ...                                                        ...
# Venezuela                                                 0.15
# Vietnam                                                   1.39
# Yemen                                                     1.84
# Zambia                                                    2.34
# Zimbabwe                                                  0.57
#
# Question     Vaccines are not safe (%)  Vaccines are not effective (%)
# Country
# Afghanistan                       4.47                            1.84
# Albania                          15.85                            8.96
# Algeria                          11.28                            7.70
# Argentina                         4.85                            2.95
# Armenia                          20.57                           12.47
# ...                                ...                             ...
# Venezuela                         4.05                            2.49
# Vietnam                           8.11                            3.57
# Yemen                             3.06                            3.22
# Zambia                           10.28                            8.15
# Zimbabwe                          3.76                            1.85
#
# [144 rows x 3 columns]

# %%
# Adding overall avg.
survey_pivot['Overall Avg. (%)'] = survey_pivot.mean(axis = 1, skipna = True)

# %%
survey_pivot
# Out:
# Question     Vaccines are not important for children to have (%)  \
# Country
# Afghanistan                                               2.10
# Albania                                                   1.67
# Algeria                                                   3.70
# Argentina                                                 1.21
# Armenia                                                  12.18
# ...                                                        ...
# Venezuela                                                 0.15
# Vietnam                                                   1.39
# Yemen                                                     1.84
# Zambia                                                    2.34
# Zimbabwe                                                  0.57
#
# Question     Vaccines are not safe (%)  Vaccines are not effective (%)  \
# Country
# Afghanistan                       4.47                            1.84
# Albania                          15.85                            8.96
# Algeria                          11.28                            7.70
# Argentina                         4.85                            2.95
# Armenia                          20.57                           12.47
# ...                                ...                             ...
# Venezuela                         4.05                            2.49
# Vietnam                           8.11                            3.57
# Yemen                             3.06                            3.22
# Zambia                           10.28                            8.15
# Zimbabwe                          3.76                            1.85
#
# Question     Overall Avg. (%)
# Country
# Afghanistan          2.803333
# Albania              8.826667
# Algeria              7.560000
# Argentina            3.003333
# Armenia             15.073333
# ...                       ...
# Venezuela            2.230000
# Vietnam              4.356667
# Yemen                2.706667
# Zambia               6.923333
# Zimbabwe             2.060000
#
# [144 rows x 4 columns]

# %%
# Saving cleaned dataset
survey_pivot.to_excel('./datasets/survey_clean.xlsx')

# %% [markdown]
# ## Immunization
#
# ### Content
# - Country Name
# - Country Code
# - Indicator Name
# - Indicator Code
# - Data from 1960 to 2018
#
# ### To keep:
# - Country Name
# - Indicator Name
# - Data 2018

# %%
immu = pd.read_csv('./datasets/WDIData.csv')
immu.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...  82.783289  83.120303  83.533457
# 3   NaN   NaN   NaN   NaN   NaN  ...  86.428272  87.070576  88.176836
# 4   NaN   NaN   NaN   NaN   NaN  ...  73.942103  75.244104  77.162305
#
#         2014       2015       2016       2017  2018  2019  Unnamed: 64
# 0        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 1        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 2  83.897596  84.171599  84.510171        NaN   NaN   NaN          NaN
# 3  87.342739  89.130121  89.678685  90.273687   NaN   NaN          NaN
# 4  75.538976  78.741152  79.665635  80.749293   NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %%
# Keeping only rows with immunization indicators
immu = immu.loc[(immu['Indicator Name'].str.contains('immunization', case = False)) 
                & (immu['Indicator Name'].str.contains('% of one-year-old children'))] 
immu
# Out:
#                           Country Name Country Code  \
# 588                         Arab World          ARB
# 2017            Caribbean small states          CSS
# 3446    Central Europe and the Baltics          CEB
# 4875        Early-demographic dividend          EAR
# 6304               East Asia & Pacific          EAS
# ...                                ...          ...
# 370699           Virgin Islands (U.S.)          VIR
# 372128              West Bank and Gaza          PSE
# 373557                     Yemen, Rep.          YEM
# 374986                          Zambia          ZMB
# 376415                        Zimbabwe          ZWE
#
#                                           Indicator Name Indicator Code  1960  \
# 588     Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 2017    Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 3446    Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 4875    Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 6304    Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# ...                                                  ...            ...   ...
# 370699  Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 372128  Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 373557  Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 374986  Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
# 376415  Immunization, HepB3 (% of one-year-old children)    SH.IMM.HEPB   NaN
#
#         1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 588      NaN   NaN   NaN   NaN   NaN  ...  89.128433  85.229495  87.024230
# 2017     NaN   NaN   NaN   NaN   NaN  ...  91.889481  94.309270  93.418916
# 3446     NaN   NaN   NaN   NaN   NaN  ...  97.141350  96.611042  96.212978
# 4875     NaN   NaN   NaN   NaN   NaN  ...  67.392136  79.147284  78.359261
# 6304     NaN   NaN   NaN   NaN   NaN  ...  92.659343  93.684316  92.679681
# ...      ...   ...   ...   ...   ...  ...        ...        ...        ...
# 370699   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 372128   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 373557   NaN   NaN   NaN   NaN   NaN  ...  69.000000  67.000000  73.000000
# 374986   NaN   NaN   NaN   NaN   NaN  ...  81.000000  78.000000  79.000000
# 376415   NaN   NaN   NaN   NaN   NaN  ...  94.000000  97.000000  95.000000
#
#              2014       2015       2016       2017       2018  2019  \
# 588     85.499756  84.614608  85.676629  86.869923  86.268804   NaN
# 2017    92.967658  92.098611  96.525429  91.311438  96.339519   NaN
# 3446    95.670205  94.271654  93.753374  93.131930  91.997551   NaN
# 4875    81.056405  84.385574  86.360561  84.690535  84.302717   NaN
# 6304    92.043236  91.692084  93.665168  92.568566  91.092703   NaN
# ...           ...        ...        ...        ...        ...   ...
# 370699        NaN        NaN        NaN        NaN        NaN   NaN
# 372128        NaN        NaN        NaN        NaN        NaN   NaN
# 373557  73.000000  69.000000  71.000000  68.000000  65.000000   NaN
# 374986  86.000000  90.000000  91.000000  94.000000  90.000000   NaN
# 376415  91.000000  87.000000  90.000000  89.000000  89.000000   NaN
#
#         Unnamed: 64
# 588             NaN
# 2017            NaN
# 3446            NaN
# 4875            NaN
# 6304            NaN
# ...             ...
# 370699          NaN
# 372128          NaN
# 373557          NaN
# 374986          NaN
# 376415          NaN
#
# [264 rows x 65 columns]

# %%
# Keeping only columns to be used
immu = immu[['Country Name', 'Indicator Name', '2018']]

# %%
# Cleaning country name
immu['Country Name'] = immu['Country Name'].apply(lambda x: x.split(',')[0])
# Out:
# /Users/marie/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Keeping only countries
immu = immu.iloc[47:]
immu.head(50)
# Out:
#                     Country Name  \
# 67751                Afghanistan
# 69180                    Albania
# 70609                    Algeria
# 72038             American Samoa
# 73467                    Andorra
# 74896                     Angola
# 76325        Antigua and Barbuda
# 77754                  Argentina
# 79183                    Armenia
# 80612                      Aruba
# 82041                  Australia
# 83470                    Austria
# 84899                 Azerbaijan
# 86328                    Bahamas
# 87757                    Bahrain
# 89186                 Bangladesh
# 90615                   Barbados
# 92044                    Belarus
# 93473                    Belgium
# 94902                     Belize
# 96331                      Benin
# 97760                    Bermuda
# 99189                     Bhutan
# 100618                   Bolivia
# 102047    Bosnia and Herzegovina
# 103476                  Botswana
# 104905                    Brazil
# 106334    British Virgin Islands
# 107763         Brunei Darussalam
# 109192                  Bulgaria
# 110621              Burkina Faso
# 112050                   Burundi
# 113479                Cabo Verde
# 114908                  Cambodia
# 116337                  Cameroon
# 117766                    Canada
# 119195            Cayman Islands
# 120624  Central African Republic
# 122053                      Chad
# 123482           Channel Islands
# 124911                     Chile
# 126340                     China
# 127769                  Colombia
# 129198                   Comoros
# 130627                     Congo
# 132056                     Congo
# 133485                Costa Rica
# 134914             Cote d'Ivoire
# 136343                   Croatia
# 137772                      Cuba
#
#                                           Indicator Name  2018
# 67751   Immunization, HepB3 (% of one-year-old children)  66.0
# 69180   Immunization, HepB3 (% of one-year-old children)  99.0
# 70609   Immunization, HepB3 (% of one-year-old children)  91.0
# 72038   Immunization, HepB3 (% of one-year-old children)   NaN
# 73467   Immunization, HepB3 (% of one-year-old children)  98.0
# 74896   Immunization, HepB3 (% of one-year-old children)  59.0
# 76325   Immunization, HepB3 (% of one-year-old children)  95.0
# 77754   Immunization, HepB3 (% of one-year-old children)  86.0
# 79183   Immunization, HepB3 (% of one-year-old children)  92.0
# 80612   Immunization, HepB3 (% of one-year-old children)   NaN
# 82041   Immunization, HepB3 (% of one-year-old children)  95.0
# 83470   Immunization, HepB3 (% of one-year-old children)  85.0
# 84899   Immunization, HepB3 (% of one-year-old children)  95.0
# 86328   Immunization, HepB3 (% of one-year-old children)  90.0
# 87757   Immunization, HepB3 (% of one-year-old children)  99.0
# 89186   Immunization, HepB3 (% of one-year-old children)  98.0
# 90615   Immunization, HepB3 (% of one-year-old children)  95.0
# 92044   Immunization, HepB3 (% of one-year-old children)  98.0
# 93473   Immunization, HepB3 (% of one-year-old children)  97.0
# 94902   Immunization, HepB3 (% of one-year-old children)  96.0
# 96331   Immunization, HepB3 (% of one-year-old children)  76.0
# 97760   Immunization, HepB3 (% of one-year-old children)   NaN
# 99189   Immunization, HepB3 (% of one-year-old children)  97.0
# 100618  Immunization, HepB3 (% of one-year-old children)  83.0
# 102047  Immunization, HepB3 (% of one-year-old children)  80.0
# 103476  Immunization, HepB3 (% of one-year-old children)  95.0
# 104905  Immunization, HepB3 (% of one-year-old children)  83.0
# 106334  Immunization, HepB3 (% of one-year-old children)   NaN
# 107763  Immunization, HepB3 (% of one-year-old children)  99.0
# 109192  Immunization, HepB3 (% of one-year-old children)  85.0
# 110621  Immunization, HepB3 (% of one-year-old children)  91.0
# 112050  Immunization, HepB3 (% of one-year-old children)  90.0
# 113479  Immunization, HepB3 (% of one-year-old children)  99.0
# 114908  Immunization, HepB3 (% of one-year-old children)  92.0
# 116337  Immunization, HepB3 (% of one-year-old children)  79.0
# 117766  Immunization, HepB3 (% of one-year-old children)  71.0
# 119195  Immunization, HepB3 (% of one-year-old children)   NaN
# 120624  Immunization, HepB3 (% of one-year-old children)  47.0
# 122053  Immunization, HepB3 (% of one-year-old children)  41.0
# 123482  Immunization, HepB3 (% of one-year-old children)   NaN
# 124911  Immunization, HepB3 (% of one-year-old children)  95.0
# 126340  Immunization, HepB3 (% of one-year-old children)  99.0
# 127769  Immunization, HepB3 (% of one-year-old children)  92.0
# 129198  Immunization, HepB3 (% of one-year-old children)  91.0
# 130627  Immunization, HepB3 (% of one-year-old children)  81.0
# 132056  Immunization, HepB3 (% of one-year-old children)  75.0
# 133485  Immunization, HepB3 (% of one-year-old children)  98.0
# 134914  Immunization, HepB3 (% of one-year-old children)  82.0
# 136343  Immunization, HepB3 (% of one-year-old children)  93.0
# 137772  Immunization, HepB3 (% of one-year-old children)  99.0

# %%
# Dropping rows with nulls data for 2018
immu = immu.dropna(axis = 0)
immu
# Out:
#        Country Name                                    Indicator Name  2018
# 67751   Afghanistan  Immunization, HepB3 (% of one-year-old children)  66.0
# 69180       Albania  Immunization, HepB3 (% of one-year-old children)  99.0
# 70609       Algeria  Immunization, HepB3 (% of one-year-old children)  91.0
# 73467       Andorra  Immunization, HepB3 (% of one-year-old children)  98.0
# 74896        Angola  Immunization, HepB3 (% of one-year-old children)  59.0
# ...             ...                                               ...   ...
# 367841    Venezuela  Immunization, HepB3 (% of one-year-old children)  60.0
# 369270      Vietnam  Immunization, HepB3 (% of one-year-old children)  75.0
# 373557        Yemen  Immunization, HepB3 (% of one-year-old children)  65.0
# 374986       Zambia  Immunization, HepB3 (% of one-year-old children)  90.0
# 376415     Zimbabwe  Immunization, HepB3 (% of one-year-old children)  89.0
#
# [184 rows x 3 columns]

# %%
# Column: % of children not vaccinated
immu['% of one years-old not vaccinated'] = [round(100 - x, 2) for x in immu['2018']]
immu = immu.drop(['2018'], axis = 1)

# %%
immu = immu.drop(['Indicator Name'], axis = 1)

# %%
immu.head()
# Out:
#       Country Name  % of one years-old not vaccinated
# 67751  Afghanistan                               34.0
# 69180      Albania                                1.0
# 70609      Algeria                                9.0
# 73467      Andorra                                2.0
# 74896       Angola                               41.0

# %%
immu.to_csv('./datasets/immu_clean.csv')

# %% [markdown]
# ## Vaccination policy
#
# Legend:
# <img src="./img/legend.png">

# %%
url = 'https://en.m.wikipedia.org/wiki/Vaccination_policy'

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
table_body = soup.find_all('tbody')[1]
rows = table_body.find_all('td')
rows_clean = [r.split('\n\n') for row in rows for r in row.text.split('\xa0\xa0')]
rows_clean = [[r.replace('\n','').split('[')[0] for r in rows] for rows in rows_clean]

# %%
df = pd.DataFrame(rows_clean[1:42], columns = rows_clean[0])
df = df[['Countries', 'Strictest policy']]
df = df.rename(columns = {'Strictest policy':'Vaccination policy'})

# %%
df.to_csv('./datasets/wiki_clean.csv')
